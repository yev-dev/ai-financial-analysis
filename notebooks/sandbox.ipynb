# %%
import pandas as pd

# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = "NVDA"

# Fetch the stock data
stock = yf.Ticker(ticker_symbol)

# Get historical market data
historical_prices = stock.history(period="max")

# Get financial fundamentals
financials = stock.financials
balance_sheet = stock.balance_sheet
cashflow = stock.cashflow

# Display the data
print("Historical Prices:")
print(historical_prices)

print("\nFinancials:")
print(financials)

print("\nBalance Sheet:")
print(balance_sheet)

print("\nCash Flow:")
print(cashflow)
# Out:
# Historical Prices:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040109    0.044765    0.035573    0.037603
# 1999-01-25 00:00:00-05:00    0.040587    0.042019    0.037603    0.041542
# 1999-01-26 00:00:00-05:00    0.042019    0.042855    0.037722    0.038319
# 1999-01-27 00:00:00-05:00    0.038438    0.039393    0.036289    0.038200
# 1999-01-28 00:00:00-05:00    0.038200    0.038438    0.037841    0.038080
# ...                               ...         ...         ...         ...
# 2026-05-08 00:00:00-04:00  213.029999  217.800003  212.889999  215.199997
# 2026-05-11 00:00:00-04:00  214.039993  222.300003  213.889999  219.440002
# 2026-05-12 00:00:00-04:00  218.550003  223.750000  214.919998  220.779999
# 2026-05-13 00:00:00-04:00  224.929993  227.839996  221.570007  225.830002
# 2026-05-14 00:00:00-04:00  229.850006  236.539993  229.300003  235.740005
#
# ...

# %%
transactions_data = pd.read_csv(r'/Users/yevgeniy/Development/Projects/Storage/credit_card_transactions.csv', index_col=0)

# %%
# Remove the unwanted index label shown as "Unnamed: 0"
transactions_data.index.name = None

# If an actual "Unnamed: 0" column exists, drop it
if "Unnamed: 0" in transactions_data.columns:
    transactions_data = transactions_data.drop(columns=["Unnamed: 0"])

transactions_data.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      long  city_pop  \
# 0                561 Perry Cove  Moravian Falls  ...  -81.1781      3495
# ...

# %%
transactions_data.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      long  city_pop  \
# 0                561 Perry Cove  Moravian Falls  ...  -81.1781      3495
# ...

# %%
transactions_data = transactions_data.sample(n=5000, random_state=42)

# %%
transactions_data.to_csv(r'/Users/yevgeniy/Development/Projects/Storage/credit_card_transactions_sample.csv', index=False)

# %%
transactions_data
